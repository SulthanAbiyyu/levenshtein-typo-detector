# %% [markdown]
# # Final Project ASD

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Text Extraction

# %% [markdown]
# ### Vectorizer

# %%
# Vectorizer Alfabetis

alphabetic_list = {
    "a": 0,
    "b": 1,
    "c": 2,
    "d": 3,
    "e": 4,
    "f": 5,
    "g": 6,
    "h": 7,
    "i": 8,
    "j": 9,
    "k": 10,
    "l": 11,
    "m": 12,
    "n": 13,
    "o": 14,
    "p": 15,
    "q": 16,
    "r": 17,
    "s": 18,
    "t": 19,
    "u": 20,
    "v": 21,
    "w": 22,
    "x": 23,
    "y": 24,
    "z": 25,
}

def vectorizer_alfabetis(text_1: str, text_2: str, padding = None, pad_num=99, pad_dim=3) -> list:
    """
    Membuat vektor dari text berdasarkan urutan alfabetis

    Args:
        padding: list yang akan diisi di akhir agar kedua vektor panjangnya sama
        pad_num: elemen padding, semakin besar maka error karena ordinalitas makin kecil
        pad_dim: dimensi padding, semakin besar maka error karena ordinalitas makin kecil

    Returns: 
        list: list hasil vektorisasi

    Raises:
        TypeError: jika input argumen text_1 dan text_2 bukan string
        TypeError: jika input argumen pad_num bukan int
    """

    if type(text_1) != str or type(text_2) != str:
        raise TypeError("text_1 dan text_2 harus string")
    if type(pad_num) != int:
        raise TypeError("pad_num harus integer")

    result_1 = [alphabetic_list[code]+1 for code in text_1]
    result_2 = [alphabetic_list[code]+1 for code in text_2]
    
    if padding:
        if len(result_1) < len(result_2):
            result_1 = result_1 + ([pad_num] * (len(result_2) - len(result_1)))
            result_1 = result_1 + [pad_num] * pad_dim
            result_2 = result_2 + [pad_num] * pad_dim
        elif len(result_2) < len(result_1):
            result_2 = result_2 + ([pad_num] * (len(result_1) - len(result_2)))
            result_1 = result_1 + [pad_num] * pad_dim
            result_2 = result_2 + [pad_num] * pad_dim
        else:
            pass
    
    return result_1, result_2


# Testing
assert vectorizer_alfabetis("ubed", "debuaa", padding=True) == ([21, 2, 5, 4, 99, 99, 99, 99, 99], [4, 5, 2, 21, 1, 1, 99, 99, 99])

# %%
# One Hot Vectorizer

# def one_hot_vec(text_1: str, text_2: str, padding = None) -> list:

# %% [markdown]
# ### Similiarity dan Distance
# #### Cosine Similiarity
# $$\text{Cosine Similiarity = }\dfrac{A \cdot B}{||A|| \ ||B||}$$

# %%
def cosine_similarity(vector_1: list, vector_2: list) -> float:
    """
    Menghitung cosine similarity antara 2 vektor

    Args:
        vector_1: list vektor 1
        vector_2: list vektor 2
    
    Returns:
        float: hasil perhitungan cosine similarity
    
    Raises:
        TypeError: jika input argumen vector_1 dan vector_2 bukan list
        ValueError: jika input argumen vector_1 dan vector_2 memiliki panjang yang berbeda
    """
    if type(vector_1) != list or type(vector_2) != list:
        raise TypeError("vector_1 dan vector_2 harus list")
    if len(vector_1) != len(vector_2):
        raise ValueError("vector_1 dan vector_2 harus panjang sama")
    
    return np.dot(vector_1, vector_2) / (np.linalg.norm(vector_1) * np.linalg.norm(vector_2))

# Testing
assert cosine_similarity([1, 2, 3], [1, 2, 3]) == 1

# %% [markdown]
# #### Euclidean Distance
#
# $$\text{Euclidean Distance} = \sqrt{\sum_{i=1}^{n} (y_{i} - x_i)^2}$$

# %%
def euclidean_distance(vector_1: list, vector_2: list) -> float:
    """
    Menghitung euclidean distance antara 2 vektor

    Args:
        vector_1: list vektor 1
        vector_2: list vektor 2
    
    Returns:
        float: hasil perhitungan euclidean distance
    """
    return np.linalg.norm(np.array(vector_1) - np.array(vector_2))

assert euclidean_distance([3,4,5], [3,4,5]) == 0

# %% [markdown]
# #### Masalah dengan alphabetic vectorizer

# %%
text1 = "ubeda"
text2 = "ubedz"
text3 = "lolo"  # Gara-gara padding dengan angka besar, jadinya keitung similiar
vector_1, vector_2 = vectorizer_alfabetis(text1, text2, padding=True)
vector_3, vector_4 = vectorizer_alfabetis(text2, text3, padding=True)
print(f"Cosine similarity antara {text1} dan {text2} adalah {cosine_similarity(vector_1, vector_2)}")
print(f"Euclidean distance antara {text1} dan {text2} adalah {euclidean_distance(vector_1, vector_2)}")
print("\n")
print(f"Cosine similarity antara {text2} dan {text3} adalah {cosine_similarity(vector_3, vector_4)}")
print(f"Euclidean distance antara {text2} dan {text3} adalah {euclidean_distance(vector_3, vector_4)}")
# Out:
# Cosine similarity antara ubeda dan ubedz adalah 0.680616410626047
# Euclidean distance antara ubeda dan ubedz adalah 25.0
#
#
# Cosine similarity antara ubedz dan lolo adalah 0.9266939507419156
# Euclidean distance antara ubedz dan lolo adalah 75.82216034906945

# %% [markdown]
# ### Solusi
# #### Levenshtein Ratio

# %%
def levenshtein_ratio(s1, s2):
    if len(s1) < len(s2):
        return levenshtein_ratio(s2, s1)
        
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    return ((max(len(s1), len(s2)) - previous_row[-1]) / max(len(s1), len(s2))) * 100

# %%
text1 = "ubeda"
text2 = "ubedz"
text3 = "lolo"


print(
    f"Levenshtein ratio antara {text1} dan {text2} adalah {levenshtein_ratio(text1, text2)} %")
print(
    f"Levenshtein ratio antara {text2} dan {text3} adalah {levenshtein_ratio(text2, text3)} %")
# Out:
# Levenshtein ratio antara ubeda dan ubedz adalah 80.0 %
# Levenshtein ratio antara ubedz dan lolo adalah 0.0 %

# %% [markdown]
# ### Import Kamus

# %%
kbbi = open('kbbi.txt', 'rb').read().lower().decode('utf-8').split("\r\n")
kbbi_map = {
    **{word: "dummy_val" for word in kbbi},
}

# %% [markdown]
# ## Prototype
#
# Optimasi pencarian similiaritas:
# 1. Menggunakan word_ngram, mencari di kamus yang mengandung kata hasil word_ngram (trigram) ditambah penghilangan kata duplikasi
# 2. Menggunakan TOLERATED_LEN, mencari kata yang panjangnya dalam range konstanta
#
# Hasil optimasi berhasil mengeliminasi : \
# Metode 1     : 72422 kata -> 13613 kata \
# Metode 1 + 2 : 72422 kata -> 11607 kata

# %%
def word_ngram(text: str):
    unigram = [t for t in text]
    bigram = [list(unigram[i:i+2]) for i in range(len(unigram)-1)]
    trigram = [list(unigram[i:i+3]) for i in range(len(unigram)-2)]

    bigram_join = [''.join(b) for b in bigram]
    trigram_join = [''.join(t) for t in trigram]

    ngram = trigram_join
    return list(set(ngram))

word_ngram("ubed")
# Out:
# ['ube', 'bed']

# %%
corpus = "saya mau tamasya berkeliling keliling kota hendsk melihat lihat pemsndangan yng ada zzzzzzzzzz".split(" ")

typo_suspect = []
for word in corpus:
    if word not in kbbi_map:
        typo_suspect.append(word)
        
search_key = [word_ngram(gram) for gram in typo_suspect]
search_key
# Out:
# [['end', 'dsk', 'hen', 'nds'],
#  ['snd', 'pem', 'ems', 'nga', 'gan', 'dan', 'nda', 'ang', 'msn'],
#  ['yng'],
#  ['zzz']]

# %%
possible_key = []
TOLERATED_LEN = 2
idx = 0
for i in search_key:
    for kb in kbbi_map.keys():
        for j in i:
            if j in kb and (len(kb) <= TOLERATED_LEN + len(typo_suspect[idx])) and (len(kb) >= TOLERATED_LEN - len(typo_suspect[idx])):
                possible_key.append(kb)
    idx += 1
                
possible_key, len(possible_key)
# Out:
# (['adenda',
#   'adendum',
#   'agenda',
#   'apendiks',
#   'bendrat',
#   'bendo',
#   'bendoro',
#   'bende',
#   'benda',
#   'bendok',
#   'bendir',
#   'berbendi',
#   'bendang',
#   'blenda',
#   'bersendu',
#   'bendol',
#   'behena',
#   'bersendi',
#   'bendar',
#   'blender',
#   'berendam',
#   'bendanya',
#   'bahenol',
#   'benduan',
#   'bendalu',
#   'bendela',
#   'bendi',
#   'berbenda',
#   'bendala',
#   'bertenda',
#   'bendara',
#   'bendesa',
#   'berhenti',
#   'bendul',
#   'brendi',
#   'berenda',
#   'bendari',
#   'bendawat',
#   'bendu',
#   'bendawi',
#   'bendera',
#   'bersenda',
#   'bendung',
#   'bendel',
#   'cendala',
#   'cendol',
#   'cendera',
#   'cenderai',
#   'cendana',
#   'cendawan',
#   'cendang',
#   'cheng',
#   'cendayam',
#   'cecendet',
#   'cenduai',
#   'cendok',
#   'cendekia',
#   'defender',
#   'dendang',
#   'dendaan',
#   'dependen',
#   'dendi',
#   'didenda',
#   'dipendam',
#   'direndam',
#   'dendeng',
#   'dendam',
#   'denda',
#   'endilau',
#   'endapan',
#   'endam',
#   'eigendom',
#   'endogami',
#   'endevia',
#   'endus',
#   'endusan',
#   'endofit',
#   'endemis',
#   'endrin',
#   'endotel',
#   'endon',
#   'emendasi',
#   'endas',
#   'ende',
#   'endang',
#   'endoterm',
#   'endemi',
#   'enduro',
#   'endut',
#   'endap',
#   'endong',
#   'endok',
#   'endomorf',
#   'enderia',
#   'endul',
#   'endasan',
#   'endonan',
#   'endorfin',
#   'endoderm',
#   'enduk',
#   'endoskop',
#   'endal',
#   'endogam',
#   'endogen',
#   'endokrin',
#   'efendi',
#   'fonds',
#   'gendam',
#   'gendaman',
#   'gendala',
#   'gendit',
#   'gendak',
#   'gender',
#   'gelendo',
#   'gendis',
#   'gendi',
#   'gendela',
#   'gelendot',
#   'gendruwo',
#   'gendar',
#   'gendong',
#   'gendir',
#   'gendeng',
#   'gendon',
#   'gendut',
#   'gendewa',
#   'genduk',
#   'gendang',
#   'gerendel',
#   'gending',
#   'gendaga',
#   'henry',
#   'hentinya',
#   'hengkang',
#   'hendak',
#   'hendak',
#   'hendam',
#   'hendam',
#   'hentikan',
#   'hening',
#   'hentian',
#   'hendi',
#   'hendi',
#   'henle',
#   'hendel',
#   'hendel',
#   'hentaman',
#   'hentak',
#   'hentar',
#   'hentakan',
#   'henti',
#   'hengit',
#   'heng',
#   'jendala',
#   'jendol',
#   'jendel',
#   'jendal',
#   'jendelan',
#   'jendela',
#   'jendrang',
#   'jendul',
#   'jendera',
#   'jenderal',
#   'kenderi',
#   'kendit',
#   'kependem',
#   'kenduduk',
#   'kendong',
#   'kendeka',
#   'kresendo',
#   'kendil',
#   'kendara',
#   'kehendak',
#   'kehendak',
#   'kendali',
#   'kendi',
#   'kendor',
#   'kendang',
#   'kendal',
#   'kendak',
#   'kendoka',
#   'komendur',
#   'kalender',
#   'kendung',
#   'kendati',
#   'kendana',
#   'kendaga',
#   'kemendur',
#   'kendo',
#   'kendur',
#   'kendala',
#   'kenduri',
#   'lendotan',
#   'lavendel',
#   'lendica',
#   'lendot',
#   'lamender',
#   'lemender',
#   'lender',
#   'lenda',
#   'lendeh',
#   'lendir',
#   'legenda',
#   'lendutan',
#   'lendaian',
#   'lenduksi',
#   'lendut',
#   'lendah',
#   'lendung',
#   'lavender',
#   'mendusta',
#   'mendidik',
#   'mendebur',
#   'mendikte',
#   'mendaga',
#   'mendidih',
#   'mendesak',
#   'mendam',
#   'melendot',
#   'melendut',
#   'mendel',
#   'mendada',
#   'menderit',
#   'mendagi',
#   'mendekih',
#   'mendedel',
#   'mendudu',
#   'menderau',
#   'mendemo',
#   'mendap',
#   'memendam',
#   'mendilak',
#   'mendikai',
#   'menduai',
#   'mendasun',
#   'mendeder',
#   'mendu',
#   'mendura',
#   'mendekut',
#   'mendedau',
#   'mendayu',
#   'melendeh',
#   'mendesir',
#   'mendua',
#   'mendiami',
#   'mendali',
#   'mendung',
#   'mendeham',
#   'mendalam',
#   'mendepun',
#   'mendemah',
#   'menderis',
#   'mendabik',
#   'mendesut',
#   'mendenda',
#   'menduru',
#   'mendanai',
#   'mendekap',
#   'mendaur',
#   'merenda',
#   'mendebah',
#   'menderun',
#   'mendapa',
#   'menderes',
#   'mendecit',
#   'menendas',
#   'mendaduk',
#   'mendebat',
#   'mendakwa',
#   'mendiris',
#   'mendacin',
#   'mendonan',
#   'mendabak',
#   'merenduk',
#   'mendesar',
#   'mendebu',
#   'mendoan',
#   'mendesah',
#   'mendetak',
#   'mendemik',
#   'mendamak',
#   'merendah',
#   'mendera',
#   'mendamba',
#   'mendudur',
#   'mendecur',
#   'mendem',
#   'mendebik',
#   'mendak',
#   'mendengu',
#   'mendril',
#   'mendupak',
#   'mendadak',
#   'mendekat',
#   'mendiani',
#   'mendetar',
#   'mendegam',
#   'mendegil',
#   'mendrel',
#   'membendi',
#   'mendeng',
#   'mendepa',
#   'menderma',
#   'menderap',
#   'merendam',
#   'mendarah',
#   'mendesis',
#   'mendut',
#   'menderu',
#   'mendunia',
#   'mendaun',
#   'merendai',
#   'mendekus',
#   'mendahan',
#   'mendahak',
#   'menyendi',
#   'mendreng',
#   'mendekam',
#   'mendaduh',
#   'mendepak',
#   'memendek',
#   'mendusin',
#   'mendirus',
#   'menduga',
#   'mendayus',
#   'mendabih',
#   'mendodet',
#   'mendarab',
#   'mendekar',
#   'mendatar',
#   'melenda',
#   'mendamik',
#   'mendukai',
#   'mendiang',
#   'mendesau',
#   'mendata',
#   'mendapat',
#   'mendedes',
#   'mendora',
#   'mendong',
#   'mendamar',
#   'mendodos',
#   'mendagel',
#   'mendosir',
#   'mendetik',
#   'mending',
#   'mendekor',
#   'mendayai',
#   'mendarat',
#   'menderek',
#   'mendira',
#   'menduri',
#   'memenda',
#   'mendedas',
#   'mendoa',
#   'mendupai',
#   'mendulag',
#   'mendaras',
#   'menderum',
#   'mendur',
#   'menderam',
#   'mendugas',
#   'mendelik',
#   'menderas',
#   'mendidis',
#   'mendalu',
#   'mendanau',
#   'mendaki',
#   'mendalih',
#   'mendasar',
#   'nenda',
#   'nendatan',
#   'nenenda',
#   'nussenda',
#   'opendim',
#   'pendek',
#   'pendiet',
#   'pendar',
#   'pendet',
#   'pendiri',
#   'pendopo',
#   'penduk',
#   'penderes',
#   'pendapat',
#   'pendaki',
#   'pendesak',
#   'pendekap',
#   'pendagel',
#   'pendak',
#   'pendaran',
#   'pendaur',
#   'pendedel',
#   'pendua',
#   'pendekar',
#   'pendana',
#   'penderek',
#   'pemendak',
#   'pendaga',
#   'pendam',
#   'pendiris',
#   'pending',
#   'pendamai',
#   'pendeder',
#   'penduduk',
#   'pendata',
#   'pendidih',
#   'pendiam',
#   'pendaduk',
#   'pendaan',
#   'penda',
#   'penderas',
#   'pendega',
#   'pendawa',
#   'pendosa',
#   'pendagi',
#   'pendamar',
#   'pendarat',
#   'pendapun',
#   'pendaman',
#   'pendamba',
#   'penderma',
#   'pendeta',
#   'pendakwa',
#   'pendebat',
#   'pendidik',
#   'pendulum',
#   'pendisko',
#   'pendadah',
#   'pendapa',
#   'pendusta',
#   'pendikte',
#   'pendok',
#   'pendahan',
#   'pendarah',
#   'pendem',
#   'penduga',
#   'penduaan',
#   'rendabel',
#   'rendahan',
#   'rendaman',
#   'rendra',
#   'rendah',
#   'renduk',
#   'rendemen',
#   'rendet',
#   'renda',
#   'rendeng',
#   'rendang',
#   'rendam',
#   'rendak',
#   'rendong',
#   'senderut',
#   'sendelan',
#   'sesendok',
#   'sependek',
#   'sendi',
#   'sendalan',
#   'slendro',
#   'sendalu',
#   'sendat',
#   'senduk',
#   'sendarat',
#   'sendu',
#   'semende',
#   'sendayan',
#   'sendiri',
#   'sendawa',
#   'selender',
#   'sendar',
#   'senduduk',
#   'senda',
#   'sendeng',
#   'sendinya',
#   'sendok',
#   'sendam',
#   'sendon',
#   'seteheng',
#   'sekendal',
#   'selendro',
#   'sendel',
#   'serendah',
#   'sendal',
#   'sendang',
#   'semenda',
#   'sende',
#   'sendaren',
#   'sender',
#   'senderik',
#   'sekendi',
#   'sending',
#   'terendah',
#   'tendo',
#   'tendens',
#   'tendon',
#   'tendang',
#   'tendanya',
#   'tenda',
#   'tendas',
#   'tendensi',
#   'terhenti',
#   'terendak',
#   'terendam',
#   'trendi',
#   'tender',
#   'vivendi',
#   'vendor',
#   'versendi',
#   'vendeta',
#   'verhenti',
#   'zending',
#   'anglap',
#   'andang-andang',
#   'andang-andang',
#   'andang-andang',
#   'anggrekwan',
#   'allamanda',
#   'angkuh',
#   'adang-adang',
#   'adang-adang',
#   'ayahanda',
#   'angkasa',
#   'angot',
#   'ancang-ancang',
#   'acerang',
#   'ananda',
#   'ayunda',
#   'anguilla',
#   'alingan',
#   'alingan',
#   'angin',
#   'angr',
#   'angkrok',
#   'asmarandana',
#   'asmarandana',
#   'angsur',
#   'angin-anginan',
#   'anggarakasih',
#   'angkringan',
#   'angkringan',
#   'angkringan',
#   'andangan',
#   'andangan',
#   'andangan',
#   'andangan',
#   'andangan',
#   'angrofobia',
#   'asongan',
#   'asongan',
#   'angkusa',
#   'alingaling',
#   'adindaku',
#   'amplang',
#   'antiradang',
#   'antiradang',
#   'adenda',
#   'angustipolia',
#   'anggah',
#   'ayeng-ayengan',
#   'ayeng-ayengan',
#   'angkal-angkal',
#   'ancangancang',
#   'ancangancang',
#   'ancangancang',
#   'arang',
#   'asungan',
#   'asungan',
#   'andam',
#   'anggak',
#   'anotang',
#   'angelecia',
#   'anakanda',
#   'ampang',
#   'angan',
#   'angan',
#   'angan',
#   'anjang-anjang',
#   'andaikan',
#   'angkut',
#   'anggerka',
#   'andaran',
#   'angkring',
#   'angker',
#   'angkut-angkut',
#   'arogansi',
#   'arogan',
#   'anggal',
#   'anggar-anggar',
#   'angglap',
#   'angah',
#   'angah',
#   'alabangka',
#   'angop',
#   'anglong',
#   'angsa',
#   'andalkan',
#   'anggar',
#   'angkup-angkup',
#   'anggotanya',
#   'anjungan',
#   'anjungan',
#   'acang',
#   'anggota',
#   'angkutan',
#   'angkatan',
#   'anda',
#   'angelesia',
#   'arungan',
#   'arungan',
#   'angkel',
#   'angiospermae',
#   'adigang',
#   'adigang',
#   'angkuk',
#   'angklung',
#   'angsu',
#   'afganistan',
#   'ada-adanyakah',
#   'angka-angka',
#   'angkar',
#   'angulata',
#   'alangkah',
#   'anggun',
#   'anggur',
#   'adibintang',
#   'awangan',
#   'awangan',
#   'awangan',
#   'anginofobia',
#   'abangan',
#   'abangan',
#   'abangan',
#   'awalengas',
#   'angguh',
#   'anorganis',
#   'asmaradana',
#   'anggorokasih',
#   'arenga',
#   'anggau',
#   'abang',
#   'anggit',
#   'adibangkit',
#   'anggai',
#   'antipembekuan',
#   'angka',
#   'asingan',
#   'asingan',
#   'ambang',
#   'andan',
#   'andan',
#   'angkit',
#   'anggukan',
#   'akang',
#   'angsana',
#   'andar',
#   'angler',
#   'acang-acang',
#   'awang',
#   'angguran',
#   'agenda',
#   'angkus',
#   'alang',
#   'angkak',
#   'angin-angin',
#   'ampiang',
#   'anginnya',
#   'anjangsono',
#   'alangan',
#   'alangan',
#   'alangan',
#   'adikanda',
#   'aderang',
#   'angiografi',
#   'anggel-anggel',
#   'andalas',
#   'awang-awang',
#   'ancangan',
#   'ancangan',
#   'ancangan',
#   'adanya',
#   'agropangan',
#   'agropangan',
#   'agropangan',
#   'angkin',
#   'andak',
#   'adegan',
#   'andamusang',
#   'andamusang',
#   'anorganik',
#   'agan',
#   'angku',
#   'arung-arungan',
#   'arung-arungan',
#   'adan',
#   'antikejang',
#   'anggabaya',
#   'alang-alangan',
#   'alang-alangan',
#   'alang-alangan',
#   'angina',
#   'anganangan',
#   'anganangan',
#   'anganangan',
#   'apem',
#   'aling-alingan',
#   'aling-alingan',
#   'andap',
#   'anggan',
#   'anggan',
#   'anghur',
#   'angit',
#   'anggu',
#   'anjangsana',
#   'angkul-angkul',
#   'alangkitae',
#   'andalan',
#   'angkur',
#   'aungan',
#   'aungan',
#   'andapita',
#   'angstrom',
#   'angkup',
#   'anjang',
#   'anghun',
#   'angket',
#   'angkaangka',
#   'acungan',
#   'acungan',
#   'ajengan',
#   'ajengan',
#   'adinda',
#   'anjangkarya',
#   'angiogenesis',
#   'angke',
#   'asmaradanta',
#   'adang',
#   'adang',
#   'angan-angan',
#   'angan-angan',
#   'angan-angan',
#   'angkat',
#   'ambacang',
#   'ajudan',
#   'anglo',
#   'anang',
#   'anganku',
#   'anganku',
#   'anganku',
#   'angora',
#   'anggapan',
#   'andalusit',
#   'anggup-anggip',
#   'angkong',
#   'angguk',
#   'angus',
#   'andang',
#   'andang',
#   'andang',
#   'anguillaris',
#   'amang',
#   'angioedema',
#   'andaikata',
#   'andaian',
#   'adiwangsa',
#   'angkara',
#   'anggua',
#   'angkaribung',
#   'antarbangsa',
#   'andai',
#   'anglikan',
#   'ayang-ayang',
#   'anyang',
#   'ayanda',
#   'angga',
#   'angut',
#   'aring-aringan',
#   'aring-aringan',
#   'andante',
#   'andante',
#   'angsurannya',
#   'awangawang',
#   'awangawang',
#   'anggaran',
#   'ajang',
#   'angluta',
#   'acutangula',
#   'alangium',
#   'angpau',
#   'angkasawan',
#   'andaman',
#   'antioksidan',
#   'andal',
#   'alang-alang',
#   'angular',
#   'abangga',
#   'anggung',
#   'angsoka',
#   'anggrek',
#   'alalunga',
#   'anggut',
#   'asango',
#   'angiologi',
#   'anggitan',
#   'anggara',
#   'antarruang',
#   'anyang-anyang',
#   'anggap',
#   'awaarang',
#   'angur',
#   'angiosperma',
#   'angon',
#   'angsuran',
#   'angkasawati',
#   'angustifolia',
#   'ambalang',
#   'allargando',
#   'ancang',
#   'angel',
#   'anglung',
#   'angsang',
#   'andaka',
#   'ada-adanya',
#   'anggul',
#   'antargolongan',
#   'antargolongan',
#   'angkuhnya',
#   'angelika',
#   'angonan',
#   'alamanda',
#   'antarangkatan',
#   'alangalang',
#   'alangalang',
#   'antiangina',
#   'bhayangkara',
#   'berkajang',
#   'bertanda',
#   'buldan',
#   'badanbadan',
#   'bergantung',
#   'bentang',
#   'blangko',
#   'berkemendang',
#   'berkemendang',
#   'berkemendang',
#   'berdangdut',
#   'berdangdut',
#   'berdampingan',
#   'berdampingan',
#   'bengal',
#   'banyuwangi',
#   'bentangan',
#   'bentangan',
#   'bentangan',
#   'berkendaraan',
#   'belontang',
#   'berganggang',
#   'berganggang',
#   'bangbarung',
#   'bayangannya',
#   'bayangannya',
#   'bayangannya',
#   'bertangisan',
#   'bangon',
#   'berambang',
#   'berpangkat',
#   'berpinggang',
#   'berpinggang',
#   'bintangnya',
#   'berjeremang',
#   'berkanjang',
#   'beranggut',
#   'barangbarang',
#   'babang',
#   'bersaingan',
#   'bersaingan',
#   'bundar',
#   'banda',
#   'berandang',
#   'berandang',
#   'berandang',
#   'beranggul',
#   'bengawan',
#   'berangin',
#   'bergelanggang',
#   'bergelanggang',
#   'blong-blongan',
#   'blong-blongan',
#   'bertarungan',
#   'bertarungan',
#   'bermagang',
#   'bermagang',
#   'bajingan',
#   'bajingan',
#   'binatang',
#   'berjantang',
#   'bercanggah',
#   'berwalang',
#   'berpeluang',
#   'berbelulang',
#   'berjuang',
#   'bernga',
#   'berlenggang',
#   'berlenggang',
#   'bercoangan',
#   'bercoangan',
#   'bercoangan',
#   'bulang-bulang',
#   'berandau',
#   'berlandas',
#   'bangat',
#   'bangat',
#   'barangnya',
#   'beriang',
#   'bangkasan',
#   'berbidan',
#   'bercabang',
#   'bingkang',
#   'bergantungan',
#   'bergantungan',
#   'bedanya',
#   'bersangai',
#   'bersangai',
#   'badannya',
#   'berenangnya',
#   'bergenang',
#   'berseregang',
#   'berseregang',
#   'balonga',
#   'berang',
#   'bebungaan',
#   'berterawang',
#   'berangkatlah',
#   'beralang',
#   'berdangka',
#   'berdangka',
#   'bertangguk',
#   'berketerangan',
#   'berketerangan',
#   'berketerangan',
#   'bergirang',
#   'bangkang',
#   'bersempang',
#   'bulangan',
#   'bulangan',
#   'bulangan',
#   'bandar',
#   'beranggapan',
#   'boplang',
#   'bintang',
#   'belembang',
#   'bangunan',
#   'berkerang',
#   'begandering',
#   'bungabungaan',
#   'bundas',
#   'bersundal',
#   'berpangkalan',
#   'buang',
#   'baplang',
#   'berpadang',
#   'berpadang',
#   'bertopang',
#   'berkang',
#   'beransang',
#   'bergeronggang',
#   'bergeronggang',
#   'belandang',
#   'belandang',
#   'belandang',
#   'berlancang',
#   'bongsang',
#   'berkemandang',
#   'berkemandang',
#   'berkemandang',
#   'bergerayangan',
#   'bergerayangan',
#   'bergerayangan',
#   'badan',
#   'bersanggakan',
#   'bercencang',
#   'berjunjungan',
#   'berjunjungan',
#   'berselendang',
#   'berselendang',
#   'berselendang',
#   'bingar',
#   'bersangatan',
#   'bersangatan',
#   'bandarsah',
#   'berkecandan',
#   'berkecandan',
#   'berganti',
#   'bercendawan',
#   'bertanggal',
#   'belanga',
#   'belanga',
#   'bangkok',
#   'berwewenang',
#   'berguncang',
#   'bangan',
#   'bangan',
#   ...],
#  11607)

# %%
suggestion = {}
for typo in typo_suspect:
    similarity_word = []
    similarity_ratio = []
    for key in possible_key:
        similarity_word.append(key)
        similarity_ratio.append(levenshtein_ratio(typo, key))
    sim_df = pd.DataFrame({"word": similarity_word, "similarity": similarity_ratio})
    sim_df = sim_df.sort_values(by="similarity", ascending=False)

    # if similiarity less than 0.5
    if all(sim_df["similarity"] < 50):
        suggestion[typo] = ["Kata tidak ditemukan di kamus"]
    else:
        suggestion[typo] = [sim_df.iloc[i]["word"] for i in range(3)]

# %%
suggestion
# Out:
# {'hendsk': ['hendak', 'hendak', 'hendak'],
#  'pemsndangan': ['pemandangan', 'pemandangan', 'pemandangan'],
#  'yng': ['yang', 'nyang', 'eyang'],
#  'zzzzzzzzzz': ['Kata tidak ditemukan di kamus']}

# %% [markdown]
# ## Main Program

# %%
corpus_raw = open("Soal ASD FP.txt", "rb").read().lower().decode('utf-8')

# %%
import re
def text_cleaning(text: str):
    text = text.replace("\n", " ")
    text = text.replace("\r", " ")
    text = text.replace("\t", " ")
    text = text.replace("  ", " ")
    text = text.lower()
    text = re.sub(r"\[[^\]]*\]", "", text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r"\([^\)]*,[^\)]*\)", "", text)
    
    # remove extra white space
    text = re.sub(r'\s+', ' ', text)
    return text

# %%
from tqdm import tqdm

corpus = text_cleaning(corpus_raw).split(" ")
corpus_unique = list(set(corpus))

print("Mencari TYPO SUSPECT...")
typo_suspect = []
for word in tqdm(corpus_unique):
    if word not in kbbi_map:
        typo_suspect.append(word)

print("===TYPO SUSPECT sudah ditemukan===")
search_key = [word_ngram(gram) for gram in typo_suspect]

print("Mencari POSSIBLE KEY...")
possible_key = []
TOLERATED_LEN = 2
idx = 0
for i in tqdm(search_key):
    for kb in kbbi_map.keys():
        for j in i:
            if j in kb and (len(kb) <= TOLERATED_LEN + len(typo_suspect[idx])) and (len(kb) >= TOLERATED_LEN - len(typo_suspect[idx])):
                possible_key.append(kb)
    idx += 1
print("===POSSIBLE KEY sudah ditemukan===")

print("Mencari SUGGESTION...")
suggestion = {}
THRESHOLD = 60
for typo in tqdm(typo_suspect):
    similarity_word = []
    similarity_ratio = []
    for key in possible_key:
        similarity_word.append(key)
        similarity_ratio.append(levenshtein_ratio(typo, key))
    sim_df = pd.DataFrame(
        {"word": similarity_word, "similarity": similarity_ratio})
    sim_df = sim_df.sort_values(by="similarity", ascending=False)

    if all(sim_df["similarity"] < THRESHOLD):
        suggestion[typo] = ["Kata tidak ditemukan di kamus"]
    else:
        suggestion[typo] = [sim_df.iloc[i]["word"] for i in range(3)]

print("===SUGGESTION sudah ditemukan===")

# %%
suggestion
# Out:
# {'adaptive': ['adaptif', 'adaptif', 'adaptif'],
#  'respon': ['respons', 'respons', 'respons'],
#  'cc': ['Kata tidak ditemukan di kamus'],
#  'shift': ['shinto', 'shinto', 'shinto'],
#  'variance': ['variansi', 'varian', 'varians'],
#  'integrated': ['integrator', 'integratif', 'integrator'],
#  'bmkg': ['Kata tidak ditemukan di kamus'],
#  'iglesias': ['diglosia', 'lasias', 'diglosia'],
#  'dianingtyas': ['dibantingnya', 'dibantingnya', 'dibantingnya'],
#  'keakurasian': ['keakuratan', 'keakuratan', 'keakuratan'],
#  'penghujan': ['penghujat', 'menghujan', 'penghujat'],
#  'rbf': ['Kata tidak ditemukan di kamus'],
#  'winkler': ['winglet', 'winglet', 'winglet'],
#  'bitwise': ['Kata tidak ditemukan di kamus'],
#  'operasinya': ['operasional', 'operasional', 'operasional'],
#  'lawrence': ['lawrensium', 'lawrensium', 'lawrensium'],
#  'function': ['union', 'fungsio', 'union'],
#  'mathurakani': ['memburakan', 'majakani', 'matahani'],
#  'giovanis': ['galvanis', 'galvanis', 'galvanis'],
#  'autoregressive': ['Kata tidak ditemukan di kamus'],
#  'mae': ['mate', 'mare', 'mate'],
#  'dibalik': ['dibatik', 'dibatik', 'dibatik'],
#  'neurofuzzy': ['Kata tidak ditemukan di kamus'],
#  'mean': ['medan', 'mekan', 'mekan'],
#  'dikodekan': ['dibolehkan', 'dikedaikan', 'dikedaikan'],
#  'roqib': ['ratib', 'rosin', 'ragib'],
#  'pertamatama': ['pertama-tama', 'pertama-tama', 'pertama-tama'],
#  'inference': ['inferensi', 'inferensi', 'inferensi'],
#  'anfis': ['anfas', 'anis', 'anis'],
#  'mape': ['ape', 'mate', 'mate'],
#  'heteroskedastisitas': ['heteroseksualitas',
#   'heteroseksualitas',
#   'heteroseksualitas'],
#  'optimasi': ['optimisasi', 'optimisasi', 'optimisasi'],
#  'ii': ['ini', 'ini', 'isi'],
#  'error': ['eror', 'eror', 'erot'],
#  'tandai': ['sandai', 'tandas', 'tanai'],
#  'fuzzy': ['Kata tidak ditemukan di kamus'],
#  'liuzhou': ['Kata tidak ditemukan di kamus'],
#  'hpsoga': ['soga', 'soga', 'eksogam'],
#  'optimization': ['optimisasi', 'optimisasi', 'optimisasi'],
#  'liu': ['liuk', 'linu', 'liur'],
#  'parameterparameter': ['Kata tidak ditemukan di kamus'],
#  'arima': ['rima', 'prima', 'nrima'],
#  'morecroft': ['mererot', 'mererot', 'modero'],
#  'string': ['saring', 'saring', 'saring'],
#  'pso': ['poso', 'ipso', 'ipso'],
#  'norm': ['norma', 'norma', 'norma'],
#  'aare': ['pare', 'sare', 'are'],
#  'onepoint': ['point', 'point', 'point'],
#  'network': ['Kata tidak ditemukan di kamus'],
#  'gálvez': ['Kata tidak ditemukan di kamus'],
#  'jackson': ['takson', 'takson', 'takson'],
#  'ekasari': ['kasasi', 'ekajati', 'kasai'],
#  'rmse': ['rase', 'rase', 'frase'],
#  'sayangnya': ['sarangnya', 'sarangnya', 'sarangnya'],
#  'percentage': ['persentase', 'persentase', 'persentase'],
#  'dinormalisasi': ['menormalisasi', 'menormalisasi', 'menormalisasi'],
#  'lowe': ['lawe', 'kowe', 'lone'],
#  'niranjan': ['niranya', 'niranya', 'niranya'],
#  'overfitting': ['keriting', 'gerinting', 'gerinting'],
#  'balitbangtan': ['batangan', 'batangan', 'kalimantan'],
#  'nuryadi': ['suryani', 'nurani', 'nurani'],
#  'vijay': ['wijaya', 'wijaya', 'wijaya'],
#  'relative': ['relatif', 'relatif', 'relatif'],
#  'diilhami': ['dialami', 'dialami', 'dialami'],
#  'perangkingan': ['peranginan', 'peranjingan', 'pelangsingan'],
#  'srivastava': ['Kata tidak ditemukan di kamus'],
#  'algorithm': ['algoritma', 'algoritma', 'algoritme'],
#  'utomo': ['ultimo', 'ultimo', 'automorf'],
#  'genetic': ['genetik', 'genetis', 'genetif'],
#  'gaussian': ['sasian', 'rasian', 'galian'],
#  'afantitis': ['analitis', 'analitis', 'analitis'],
#  'moving': ['moringa', 'moringa', 'moringa'],
#  'node': ['anode', 'anode', 'anode'],
#  'broomhead': ['Kata tidak ditemukan di kamus'],
#  'back': ['bacek', 'bacik', 'bacak'],
#  'karangploso': ['paraglosa', 'paraglosa', 'paraglosa'],
#  'coefficient': ['koefisien', 'koefisien', 'koefisien'],
#  'hybrid': ['hibrid', 'hibrid', 'hibrida'],
#  'rbfga': ['raga', 'raga', 'raga'],
#  'euclidean': ['Kata tidak ditemukan di kamus'],
#  'wavelet': ['novelet', 'novelet', 'novelet'],
#  'inisialisasi': ['visualisasi', 'sosialisasi', 'sosialisasi'],
#  'nonlinier': ['nonmiliter', 'nonmiliter', 'nonmiliter'],
#  'wu': ['Kata tidak ditemukan di kamus'],
#  'wei': ['wein', 'werit', 'welit'],
#  'absolute': ['absolut', 'absolut', 'absolut'],
#  'nn': ['non', 'nian', 'nini'],
#  'range': ['dange', 'rang', 'rangu'],
#  'invers': ['inversi', 'inversi', 'inversi'],
#  'thampi': ['tampi', 'tampi', 'tampi'],
#  'correlation': ['bergelatin', 'korelatif', 'korelatif'],
#  'root': ['rosot', 'rosot', 'procot'],
#  'berretti': ['berpeti', 'berhenti', 'berhenti'],
#  'staklim': ['taklim', 'taklim', 'taklim'],
#  'square': ['suari', 'suara', 'suara'],
#  'fitness': ['Kata tidak ditemukan di kamus'],
#  'squared': ['Kata tidak ditemukan di kamus'],
#  'average': ['Kata tidak ditemukan di kamus'],
#  'ingragustari': ['Kata tidak ditemukan di kamus'],
#  'rbfnn': ['Kata tidak ditemukan di kamus'],
#  'swarm': ['swarga', 'soarma', 'soarma'],
#  'aktualnya': ['akalnya', 'akalnya', 'akalnya'],
#  'particle': ['partial', 'partial', 'partial'],
#  'systems': ['sistemis', 'sistemis', 'sistem'],
#  'diaplikasikan': ['direlisasikan', 'direlisasikan', 'direlisasikan'],
#  'propagation': ['protalamion', 'protalamion', 'protalamion']}

# %% [markdown]
# ## Prototype Dengan Interface

# %%
def pipeline_dict(text):
    corpus = text_cleaning(text).split(" ")

    corpus_unique = list(set(corpus))
    typo_suspect = []
    for word in corpus_unique:
        if word not in kbbi_map:
            typo_suspect.append(word)

    search_key = [word_ngram(gram) for gram in typo_suspect]

    possible_key = []


    TOLERATED_LEN = 2
    idx = 0
    for i in search_key:
        for kb in kbbi_map.keys():
            for j in i:
                if j in kb and (len(kb) <= TOLERATED_LEN + len(typo_suspect[idx])) and (len(kb) >= TOLERATED_LEN - len(typo_suspect[idx])):
                    possible_key.append(kb)
        idx += 1

    suggestion = {}
    THRESHOLD = 60
    for typo in typo_suspect:
        similarity_word = []
        similarity_ratio = []
        for key in possible_key:
            similarity_word.append(key)
            similarity_ratio.append(levenshtein_ratio(typo, key))
        sim_df = pd.DataFrame(
            {"word": similarity_word, "similarity": similarity_ratio})
        sim_df = sim_df.sort_values(by="similarity", ascending=False)

        if all(sim_df["similarity"] < THRESHOLD):
            suggestion[typo] = ["Kata tidak ditemukan di kamus"]
        else:
            suggestion[typo] = [
                (sim_df.iloc[i]["word"], sim_df.iloc[i]["similarity"]) for i in range(3)]
    return suggestion

# %%
def pipeline(text):
    corpus = text_cleaning(text).split(" ")

    corpus_unique = list(set(corpus))
    typo_suspect = []
    for word in corpus_unique:
        if word not in kbbi_map:
            typo_suspect.append(word)

    search_key = [word_ngram(gram) for gram in typo_suspect]

    possible_key = []


    TOLERATED_LEN = 2
    idx = 0
    for i in search_key:
        for kb in kbbi_map.keys():
            for j in i:
                if j in kb and (len(kb) <= TOLERATED_LEN + len(typo_suspect[idx])) and (len(kb) >= TOLERATED_LEN - len(typo_suspect[idx])):
                    possible_key.append(kb)
        idx += 1

    suggestion = {}
    THRESHOLD = 60
    if len(typo_suspect) == 0:
        return "Tidak ada typo"
        
    for typo in typo_suspect:
        similarity_word = []
        similarity_ratio = []
        for key in possible_key:
            similarity_word.append(key)
            similarity_ratio.append(levenshtein_ratio(typo, key))
        sim_df = pd.DataFrame(
            {"word": similarity_word, "similarity": similarity_ratio})
        sim_df = sim_df.sort_values(by="similarity", ascending=False)

        if all(sim_df["similarity"] < THRESHOLD):
            suggestion[typo] = ["Kata tidak ditemukan di kamus"]
        else:
            suggestion[typo] = [
                (sim_df.iloc[i]["word"], sim_df.iloc[i]["similarity"]) for i in range(3)]
        hasil = ""


        for typo, s in suggestion.items():
            if suggestion[typo] == ["Kata tidak ditemukan di kamus"]:
                hasil += f"{typo} tidak ditemukan di kamus\n"
            else:
                hasil += f"'{typo}' dapat ditulis sebagai:\n"
                idx = 1
                for i in suggestion[typo]:
                    hasil += f"{idx}. {i[0]} ({round(i[1])} %)\n"
                    idx += 1
                hasil += "\n"

    return hasil

# %%
suggestion = pipeline("says kots")

# %%
import gradio as gr
DESCR = "Prototype typo detector bahasa indonesia untuk projek final pada mata kuliah ASD"
ARTCL = """"""
# Gradio custom css
custom_css = """
@font-face {
  font-family: 'poppins';
  font-style: normal;
  font-weight: 400, 700;
  src: url(https://fonts.gstatic.com/s/poppins/v20/pxiEyp8kv8JHgFVrJJbecmNE.woff2) format('woff2');
  unicode-range: U+0900-097F, U+1CD0-1CF6, U+1CF8-1CF9, U+200C-200D, U+20A8, U+20B9, U+25CC, U+A830-A839, U+A8E0-A8FB;
}
/* latin-ext */
@font-face {
  font-family: 'poppins';
  font-style: normal;
  font-weight: 400, 700;
  src: url(https://fonts.gstatic.com/s/poppins/v20/pxiEyp8kv8JHgFVrJJnecmNE.woff2) format('woff2');
  unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
}
/* latin */
@font-face {
  font-family: 'poppins';
  font-style: normal;
  font-weight: 400, 900;
  src: url(https://fonts.gstatic.com/s/poppins/v20/pxiEyp8kv8JHgFVrJJfecg.woff2) format('woff2');
  unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
}
.title {
    font-family: poppins !important;
    font-weight: bold !important;
}
.description {
    font-family: poppins !important;
    font-weight: 400 !important;
    font-size: 14px !important;
}
.article {
    font-family: poppins !important;
    font-weight: 400 !important;
    
}
.panel_button {
    font-weight: 400 !important;
}
.panel_header {
    font-weight: 400 !important;
}
*{
    font-family: poppins !important;
}
"""

demo = gr.Interface(fn=pipeline, inputs="text", outputs="text", examples=["Says mau tamasya. Berkeliling keliling kots", "Ada anak bertsnya pada bapaknys"], examples_per_page=10, live=False, layout="unaligned",
                    theme="dark-peach",css=custom_css, title="TYPO DETECTOR KELOMPOK 5", description=DESCR, article=ARTCL, thumbnail=None, allow_flagging="never")

demo.launch(share=True)
